# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# Load CSV file with both interval and composite records
df = pd.read_csv("data.csv")

# Convert date columns to datetime format
df['START_DATE'] = pd.to_datetime(df['START_DATE'], errors='coerce', format="%m/%d/%Y")
df['END_DATE'] = pd.to_datetime(df['END_DATE'], errors='coerce', format="%m/%d/%Y")
df['b_value'] = 0.1
# Separate interval and composite records
# interval_df = df[df['record_type'] == 'interval'].copy()
# composite_df = df[df['record_type'] == 'composite'].copy()

# Calculate repo length (in years assuming 360-day year)
df['repoLen'] = (df['END_DATE'] - df['START_DATE']).dt.days / 360

# Function to compute the exposure (overlapping duration in years) for each composite row
def calculate_tm(row, interval_df):
    tm_values = []
    for _, b_row in interval_df.iterrows():
        # Find the overlapping period between composite and interval
        start_overlap = max(row['START_DATE'], b_row['START_DATE'])
        end_overlap = min(row['END_DATE'], b_row['END_DATE'])
        overlap_days = (end_overlap - start_overlap).days
        # Convert overlap days to years (360-day basis)
        exposure = max(0, overlap_days) / 360
        tm_values.append(exposure)
    return np.array(tm_values)

# Compute exposure vector for each composite record
df['expo'] = df.apply(lambda row: calculate_tm(row, df), axis=1)

# Compute model rate for each composite record using dot product
def calculate_model_rate(row, b_vector):
    exposure_vector = row['expo']
    tm_dot_b = np.dot(exposure_vector, b_vector)
    return (np.exp(tm_dot_b) - 1) / row['repoLen'] if row['repoLen'] > 0 else np.nan

# b_value vector from interval records
b_vector = df['b_value'].values

# Apply model rate calculation
df['model_rate'] = df.apply(lambda row: calculate_model_rate(row, b_vector), axis=1)

# Display final results
print(df[['START_DATE', 'END_DATE', 'repoLen', 'model_rate']])

# Optionally save to CSV
df.to_csv("composite_rates_with_model.csv", index=False)
# Out:
#    START_DATE   END_DATE   repoLen  model_rate
# 0  2025-05-06 2025-05-07  0.002778    0.400222
# 1  2025-05-07 2025-05-08  0.002778    1.503129
# 2  2025-05-07 2025-05-09  0.005556    1.506267
# 3  2025-05-08 2025-05-09  0.002778    1.503129
# 4  2025-05-07 2025-05-13  0.016667    1.382350
# 5  2025-05-06 2025-05-16  0.027778    1.251254
# 6  2025-05-07 2025-05-20  0.036111    1.314877
# 7  2025-05-06 2025-05-21  0.041667    1.244527
# 8  2025-05-07 2025-05-21  0.038889    1.303386
# 9  2025-05-07 2025-05-27  0.055556    1.198194
# 10 2025-05-07 2025-05-28  0.058333    1.181813
# 11 2025-05-06 2025-05-30  0.066667    1.114458
# 12 2025-05-07 2025-05-30  0.063889    1.144239
# 13 2025-05-07 2025-06-02  0.072222    1.074251
# 14 2025-05-07 2025-06-06  0.083333    0.988616
# 15 2025-05-07 2025-06-13  0.102778    0.863193
# 16 2025-05-07 2025-08-15  0.277778    0.458989
# 17 2025-05-15 2025-08-15  0.255556    0.370887
# 18 2025-08-15 2025-10-15  0.169444    0.100852
# 19 2025-10-15 2025-12-15  0.169444    0.100852
# 20 2025-12-15 2026-02-17  0.177778    0.100894
# 21 2026-02-17 2026-04-17  0.163889    0.100824
# 22 2026-04-17 2026-06-17  0.169444    0.100852
# 23 2026-06-17 2026-08-17  0.169444    0.100852
# 24 2026-08-17 2026-10-19  0.175000    0.100880
# 25 2026-10-19 2026-12-21  0.175000    0.100880
# 26 2026-12-21 2027-02-22  0.175000    0.100880
# 27 2027-02-22 2027-04-22  0.163889    0.100824
# 28 2027-04-22 2027-06-22  0.169444    0.100852

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Define the B_VALUE
B_VALUE = 0.1

# Create DataFrame from the provided data
# Clean up the data (some rows have formatting issues)
data = [
    ["5/6/2025", "5/6/2025", "5/7/2025", 4.3473617],
    ["5/6/2025", "5/7/2025", "5/8/2025", 4.3583495],
    ["5/6/2025", "5/7/2025", "5/9/2025", 4.4000002],
    ["5/6/2025", "5/8/2025", "5/9/2025", 4.4000009],
    ["5/6/2025", "5/7/2025", "5/13/2025", 4.3967164],
    ["5/6/2025", "5/6/2025", "5/16/2025", 4.3799998],
    ["5/6/2025", "5/7/2025", "5/20/2025", 4.4000002],
    ["5/6/2025", "5/6/2025", "5/21/2025", 4.4100002],
    ["5/6/2025", "5/7/2025", "5/21/2025", 4.4],
    ["5/6/2025", "5/7/2025", "5/27/2025", 4.3912443],
    ["5/6/2025", "5/7/2025", "5/28/2025", 4.3579999],
    ["5/6/2025", "5/6/2025", "5/30/2025", 4.4],
    ["5/6/2025", "5/7/2025", "5/30/2025", 4.3725001],
    ["5/6/2025", "5/7/2025", "6/2/2025", 4.4187439],
    ["5/6/2025", "5/7/2025", "6/6/2025", 4.4300001],
    ["5/6/2025", "5/7/2025", "6/13/2025", 4.42],
    ["5/6/2025", "5/7/2025", "8/15/2025", 4.3915022],
    ["5/6/2025", "5/15/2025", "8/15/2025", 4.3764901],
    ["5/6/2025", "8/15/2025", "10/15/2025", 4.3764901],
    ["5/6/2025", "10/15/2025", "12/15/2025", 4.3764901],
    ["5/6/2025", "12/15/2025", "2/17/2026", 4.3764901],
    ["5/6/2025", "2/17/2026", "4/17/2026", 4.3764901],
    ["5/6/2025", "4/17/2026", "6/17/2026", 4.3764901],
    ["5/6/2025", "6/17/2026", "8/17/2026", 4.3764901],
    ["5/6/2025", "8/17/2026", "10/19/2026", 4.3764901],
    ["5/6/2025", "10/19/2026", "12/21/2026", 4.3764901],
    ["5/6/2025", "12/21/2026", "2/22/2027", 4.3764901],
    ["5/6/2025", "2/22/2027", "4/22/2027", 4.3764901],
    ["5/6/2025", "4/22/2027", "6/22/2027", 4.3764901]
]

df = pd.DataFrame(data, columns=["BUSINESS_DATE", "START_DATE", "END_DATE", "COMPOSITE_REPO_RATE"])

# Convert dates to datetime objects for calculations
for col in ["BUSINESS_DATE", "START_DATE", "END_DATE"]:
    df[col] = pd.to_datetime(df[col], format="%m/%d/%Y")

# Calculate time differences in days
df["DAYS_DIFF"] = (df["END_DATE"] - df["START_DATE"]).dt.days

# Display the initial data
print("Initial Data:")
print(df)

# Implement the calculation with the formula
def calculate_final_output(df, b_value):
    n = len(df)
    result = np.zeros(n)
    
    print("\nStep-by-Step Implementation:")
    
    for i in range(n):
        sum_term = 0
        for j in range(n):
            # Calculate the appropriate term based on days difference
            if i != j:
                days_diff_i = df.loc[i, "DAYS_DIFF"]
                days_diff_j = df.loc[j, "DAYS_DIFF"]
                repo_rate_j = df.loc[j, "COMPOSITE_REPO_RATE"]
                
                weight = b_value / (abs(days_diff_i - days_diff_j) + b_value)
                sum_term += weight * repo_rate_j
                
                print(f"  For i={i}, j={j}:")
                print(f"    days_diff_i = {days_diff_i}, days_diff_j = {days_diff_j}")
                print(f"    weight = {b_value} / (|{days_diff_i} - {days_diff_j}| + {b_value}) = {weight:.6f}")
                print(f"    term = {weight:.6f} * {repo_rate_j} = {weight * repo_rate_j:.6f}")
        
        # Normalize by dividing by the sum of weights
        sum_weights = 0
        for j in range(n):
            if i != j:
                days_diff_i = df.loc[i, "DAYS_DIFF"]
                days_diff_j = df.loc[j, "DAYS_DIFF"]
                sum_weights += b_value / (abs(days_diff_i - days_diff_j) + b_value)
        
        # Calculate the final result for this row
        if sum_weights > 0:
            result[i] = sum_term / sum_weights
        else:
            result[i] = df.loc[i, "COMPOSITE_REPO_RATE"]
        
        print(f"\n  For i={i}:")
        print(f"    Sum of weights = {sum_weights:.6f}")
        print(f"    Final result = {sum_term:.6f} / {sum_weights:.6f} = {result[i]:.6f}")
        print()
    
    return result

# Calculate the final output
final_output = calculate_final_output(df, B_VALUE)

# Add the result to the DataFrame
df["FINAL_OUTPUT"] = final_output

# Display the final result
print("\nFinal Result:")
print(df[["BUSINESS_DATE", "START_DATE", "END_DATE", "DAYS_DIFF", "COMPOSITE_REPO_RATE", "FINAL_OUTPUT"]])

# For a cleaner view
result_df = df[["BUSINESS_DATE", "START_DATE", "END_DATE", "DAYS_DIFF", "COMPOSITE_REPO_RATE", "FINAL_OUTPUT"]]
result_df.to_csv("repo_rate_calculation_results.csv", index=False)
print("\nResults saved to repo_rate_calculation_results.csv")
# Out:
# Initial Data:
#    BUSINESS_DATE START_DATE   END_DATE  COMPOSITE_REPO_RATE  DAYS_DIFF
# 0     2025-05-06 2025-05-06 2025-05-07             4.347362          1
# 1     2025-05-06 2025-05-07 2025-05-08             4.358350          1
# 2     2025-05-06 2025-05-07 2025-05-09             4.400000          2
# 3     2025-05-06 2025-05-08 2025-05-09             4.400001          1
# 4     2025-05-06 2025-05-07 2025-05-13             4.396716          6
# 5     2025-05-06 2025-05-06 2025-05-16             4.380000         10
# 6     2025-05-06 2025-05-07 2025-05-20             4.400000         13
# 7     2025-05-06 2025-05-06 2025-05-21             4.410000         15
# 8     2025-05-06 2025-05-07 2025-05-21             4.400000         14
# 9     2025-05-06 2025-05-07 2025-05-27             4.391244         20
# 10    2025-05-06 2025-05-07 2025-05-28             4.358000         21
# 11    2025-05-06 2025-05-06 2025-05-30             4.400000         24
# 12    2025-05-06 2025-05-07 2025-05-30             4.372500         23
# 13    2025-05-06 2025-05-07 2025-06-02             4.418744         26
# 14    2025-05-06 2025-05-07 2025-06-06             4.430000         30
# 15    2025-05-06 2025-05-07 2025-06-13             4.420000         37
# 16    2025-05-06 2025-05-07 2025-08-15             4.391502        100
# 17    2025-05-06 2025-05-15 2025-08-15             4.376490         92
# 18    2025-05-06 2025-08-15 2025-10-15             4.376490         61
# 19    2025-05-06 2025-10-15 2025-12-15             4.376490         61
# 20    2025-05-06 2025-12-15 2026-02-17             4.376490         64
# 21    2025-05-06 2026-02-17 2026-04-17             4.376490         59
# 22    2025-05-06 2026-04-17 2026-06-17             4.376490         61
# 23    2025-05-06 2026-06-17 2026-08-17             4.376490         61
# 24    2025-05-06 2026-08-17 2026-10-19             4.376490         63
# 25    2025-05-06 2026-10-19 2026-12-21             4.376490         63
# 26    2025-05-06 2026-12-21 2027-02-22             4.376490         63
# 27    2025-05-06 2027-02-22 2027-04-22             4.376490         59
# 28    2025-05-06 2027-04-22 2027-06-22             4.376490         61
#
# Step-by-Step Implementation:
#   For i=0, j=1:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.3583495 = 4.358350
#   For i=0, j=2:
#     days_diff_i = 1, days_diff_j = 2
#     weight = 0.1 / (|1 - 2| + 0.1) = 0.090909
#     term = 0.090909 * 4.4000002 = 0.400000
#   For i=0, j=3:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.4000009 = 4.400001
#   For i=0, j=4:
#     days_diff_i = 1, days_diff_j = 6
#     weight = 0.1 / (|1 - 6| + 0.1) = 0.019608
#     term = 0.019608 * 4.3967164 = 0.086210
#   For i=0, j=5:
#     days_diff_i = 1, days_diff_j = 10
#     weight = 0.1 / (|1 - 10| + 0.1) = 0.010989
#     term = 0.010989 * 4.3799998 = 0.048132
#   For i=0, j=6:
#     days_diff_i = 1, days_diff_j = 13
#     weight = 0.1 / (|1 - 13| + 0.1) = 0.008264
#     term = 0.008264 * 4.4000002 = 0.036364
#   For i=0, j=7:
#     days_diff_i = 1, days_diff_j = 15
#     weight = 0.1 / (|1 - 15| + 0.1) = 0.007092
#     term = 0.007092 * 4.4100002 = 0.031277
#   For i=0, j=8:
#     days_diff_i = 1, days_diff_j = 14
#     weight = 0.1 / (|1 - 14| + 0.1) = 0.007634
#     term = 0.007634 * 4.4 = 0.033588
#   For i=0, j=9:
#     days_diff_i = 1, days_diff_j = 20
#     weight = 0.1 / (|1 - 20| + 0.1) = 0.005236
#     term = 0.005236 * 4.3912443 = 0.022991
#   For i=0, j=10:
#     days_diff_i = 1, days_diff_j = 21
#     weight = 0.1 / (|1 - 21| + 0.1) = 0.004975
#     term = 0.004975 * 4.3579999 = 0.021682
#   For i=0, j=11:
#     days_diff_i = 1, days_diff_j = 24
#     weight = 0.1 / (|1 - 24| + 0.1) = 0.004329
#     term = 0.004329 * 4.4 = 0.019048
#   For i=0, j=12:
#     days_diff_i = 1, days_diff_j = 23
#     weight = 0.1 / (|1 - 23| + 0.1) = 0.004525
#     term = 0.004525 * 4.3725001 = 0.019785
#   For i=0, j=13:
#     days_diff_i = 1, days_diff_j = 26
#     weight = 0.1 / (|1 - 26| + 0.1) = 0.003984
#     term = 0.003984 * 4.4187439 = 0.017605
#   For i=0, j=14:
#     days_diff_i = 1, days_diff_j = 30
#     weight = 0.1 / (|1 - 30| + 0.1) = 0.003436
#     term = 0.003436 * 4.4300001 = 0.015223
#   For i=0, j=15:
#     days_diff_i = 1, days_diff_j = 37
#     weight = 0.1 / (|1 - 37| + 0.1) = 0.002770
#     term = 0.002770 * 4.42 = 0.012244
#   For i=0, j=16:
#     days_diff_i = 1, days_diff_j = 100
#     weight = 0.1 / (|1 - 100| + 0.1) = 0.001009
#     term = 0.001009 * 4.3915022 = 0.004431
#   For i=0, j=17:
#     days_diff_i = 1, days_diff_j = 92
#     weight = 0.1 / (|1 - 92| + 0.1) = 0.001098
#     term = 0.001098 * 4.3764901 = 0.004804
#   For i=0, j=18:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=0, j=19:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=0, j=20:
#     days_diff_i = 1, days_diff_j = 64
#     weight = 0.1 / (|1 - 64| + 0.1) = 0.001585
#     term = 0.001585 * 4.3764901 = 0.006936
#   For i=0, j=21:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=0, j=22:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=0, j=23:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=0, j=24:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=0, j=25:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=0, j=26:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=0, j=27:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=0, j=28:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#
#   For i=0:
#     Sum of weights = 2.194036
#     Final result = 9.611286 / 2.194036 = 4.380643
#
#   For i=1, j=0:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.3473617 = 4.347362
#   For i=1, j=2:
#     days_diff_i = 1, days_diff_j = 2
#     weight = 0.1 / (|1 - 2| + 0.1) = 0.090909
#     term = 0.090909 * 4.4000002 = 0.400000
#   For i=1, j=3:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.4000009 = 4.400001
#   For i=1, j=4:
#     days_diff_i = 1, days_diff_j = 6
#     weight = 0.1 / (|1 - 6| + 0.1) = 0.019608
#     term = 0.019608 * 4.3967164 = 0.086210
#   For i=1, j=5:
#     days_diff_i = 1, days_diff_j = 10
#     weight = 0.1 / (|1 - 10| + 0.1) = 0.010989
#     term = 0.010989 * 4.3799998 = 0.048132
#   For i=1, j=6:
#     days_diff_i = 1, days_diff_j = 13
#     weight = 0.1 / (|1 - 13| + 0.1) = 0.008264
#     term = 0.008264 * 4.4000002 = 0.036364
#   For i=1, j=7:
#     days_diff_i = 1, days_diff_j = 15
#     weight = 0.1 / (|1 - 15| + 0.1) = 0.007092
#     term = 0.007092 * 4.4100002 = 0.031277
#   For i=1, j=8:
#     days_diff_i = 1, days_diff_j = 14
#     weight = 0.1 / (|1 - 14| + 0.1) = 0.007634
#     term = 0.007634 * 4.4 = 0.033588
#   For i=1, j=9:
#     days_diff_i = 1, days_diff_j = 20
#     weight = 0.1 / (|1 - 20| + 0.1) = 0.005236
#     term = 0.005236 * 4.3912443 = 0.022991
#   For i=1, j=10:
#     days_diff_i = 1, days_diff_j = 21
#     weight = 0.1 / (|1 - 21| + 0.1) = 0.004975
#     term = 0.004975 * 4.3579999 = 0.021682
#   For i=1, j=11:
#     days_diff_i = 1, days_diff_j = 24
#     weight = 0.1 / (|1 - 24| + 0.1) = 0.004329
#     term = 0.004329 * 4.4 = 0.019048
#   For i=1, j=12:
#     days_diff_i = 1, days_diff_j = 23
#     weight = 0.1 / (|1 - 23| + 0.1) = 0.004525
#     term = 0.004525 * 4.3725001 = 0.019785
#   For i=1, j=13:
#     days_diff_i = 1, days_diff_j = 26
#     weight = 0.1 / (|1 - 26| + 0.1) = 0.003984
#     term = 0.003984 * 4.4187439 = 0.017605
#   For i=1, j=14:
#     days_diff_i = 1, days_diff_j = 30
#     weight = 0.1 / (|1 - 30| + 0.1) = 0.003436
#     term = 0.003436 * 4.4300001 = 0.015223
#   For i=1, j=15:
#     days_diff_i = 1, days_diff_j = 37
#     weight = 0.1 / (|1 - 37| + 0.1) = 0.002770
#     term = 0.002770 * 4.42 = 0.012244
#   For i=1, j=16:
#     days_diff_i = 1, days_diff_j = 100
#     weight = 0.1 / (|1 - 100| + 0.1) = 0.001009
#     term = 0.001009 * 4.3915022 = 0.004431
#   For i=1, j=17:
#     days_diff_i = 1, days_diff_j = 92
#     weight = 0.1 / (|1 - 92| + 0.1) = 0.001098
#     term = 0.001098 * 4.3764901 = 0.004804
#   For i=1, j=18:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=1, j=19:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=1, j=20:
#     days_diff_i = 1, days_diff_j = 64
#     weight = 0.1 / (|1 - 64| + 0.1) = 0.001585
#     term = 0.001585 * 4.3764901 = 0.006936
#   For i=1, j=21:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=1, j=22:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=1, j=23:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=1, j=24:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=1, j=25:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=1, j=26:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=1, j=27:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=1, j=28:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#
#   For i=1:
#     Sum of weights = 2.194036
#     Final result = 9.600299 / 2.194036 = 4.375635
#
#   For i=2, j=0:
#     days_diff_i = 2, days_diff_j = 1
#     weight = 0.1 / (|2 - 1| + 0.1) = 0.090909
#     term = 0.090909 * 4.3473617 = 0.395215
#   For i=2, j=1:
#     days_diff_i = 2, days_diff_j = 1
#     weight = 0.1 / (|2 - 1| + 0.1) = 0.090909
#     term = 0.090909 * 4.3583495 = 0.396214
#   For i=2, j=3:
#     days_diff_i = 2, days_diff_j = 1
#     weight = 0.1 / (|2 - 1| + 0.1) = 0.090909
#     term = 0.090909 * 4.4000009 = 0.400000
#   For i=2, j=4:
#     days_diff_i = 2, days_diff_j = 6
#     weight = 0.1 / (|2 - 6| + 0.1) = 0.024390
#     term = 0.024390 * 4.3967164 = 0.107237
#   For i=2, j=5:
#     days_diff_i = 2, days_diff_j = 10
#     weight = 0.1 / (|2 - 10| + 0.1) = 0.012346
#     term = 0.012346 * 4.3799998 = 0.054074
#   For i=2, j=6:
#     days_diff_i = 2, days_diff_j = 13
#     weight = 0.1 / (|2 - 13| + 0.1) = 0.009009
#     term = 0.009009 * 4.4000002 = 0.039640
#   For i=2, j=7:
#     days_diff_i = 2, days_diff_j = 15
#     weight = 0.1 / (|2 - 15| + 0.1) = 0.007634
#     term = 0.007634 * 4.4100002 = 0.033664
#   For i=2, j=8:
#     days_diff_i = 2, days_diff_j = 14
#     weight = 0.1 / (|2 - 14| + 0.1) = 0.008264
#     term = 0.008264 * 4.4 = 0.036364
#   For i=2, j=9:
#     days_diff_i = 2, days_diff_j = 20
#     weight = 0.1 / (|2 - 20| + 0.1) = 0.005525
#     term = 0.005525 * 4.3912443 = 0.024261
#   For i=2, j=10:
#     days_diff_i = 2, days_diff_j = 21
#     weight = 0.1 / (|2 - 21| + 0.1) = 0.005236
#     term = 0.005236 * 4.3579999 = 0.022817
#   For i=2, j=11:
#     days_diff_i = 2, days_diff_j = 24
#     weight = 0.1 / (|2 - 24| + 0.1) = 0.004525
#     term = 0.004525 * 4.4 = 0.019910
#   For i=2, j=12:
#     days_diff_i = 2, days_diff_j = 23
#     weight = 0.1 / (|2 - 23| + 0.1) = 0.004739
#     term = 0.004739 * 4.3725001 = 0.020723
#   For i=2, j=13:
#     days_diff_i = 2, days_diff_j = 26
#     weight = 0.1 / (|2 - 26| + 0.1) = 0.004149
#     term = 0.004149 * 4.4187439 = 0.018335
#   For i=2, j=14:
#     days_diff_i = 2, days_diff_j = 30
#     weight = 0.1 / (|2 - 30| + 0.1) = 0.003559
#     term = 0.003559 * 4.4300001 = 0.015765
#   For i=2, j=15:
#     days_diff_i = 2, days_diff_j = 37
#     weight = 0.1 / (|2 - 37| + 0.1) = 0.002849
#     term = 0.002849 * 4.42 = 0.012593
#   For i=2, j=16:
#     days_diff_i = 2, days_diff_j = 100
#     weight = 0.1 / (|2 - 100| + 0.1) = 0.001019
#     term = 0.001019 * 4.3915022 = 0.004477
#   For i=2, j=17:
#     days_diff_i = 2, days_diff_j = 92
#     weight = 0.1 / (|2 - 92| + 0.1) = 0.001110
#     term = 0.001110 * 4.3764901 = 0.004857
#   For i=2, j=18:
#     days_diff_i = 2, days_diff_j = 61
#     weight = 0.1 / (|2 - 61| + 0.1) = 0.001692
#     term = 0.001692 * 4.3764901 = 0.007405
#   For i=2, j=19:
#     days_diff_i = 2, days_diff_j = 61
#     weight = 0.1 / (|2 - 61| + 0.1) = 0.001692
#     term = 0.001692 * 4.3764901 = 0.007405
#   For i=2, j=20:
#     days_diff_i = 2, days_diff_j = 64
#     weight = 0.1 / (|2 - 64| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=2, j=21:
#     days_diff_i = 2, days_diff_j = 59
#     weight = 0.1 / (|2 - 59| + 0.1) = 0.001751
#     term = 0.001751 * 4.3764901 = 0.007665
#   For i=2, j=22:
#     days_diff_i = 2, days_diff_j = 61
#     weight = 0.1 / (|2 - 61| + 0.1) = 0.001692
#     term = 0.001692 * 4.3764901 = 0.007405
#   For i=2, j=23:
#     days_diff_i = 2, days_diff_j = 61
#     weight = 0.1 / (|2 - 61| + 0.1) = 0.001692
#     term = 0.001692 * 4.3764901 = 0.007405
#   For i=2, j=24:
#     days_diff_i = 2, days_diff_j = 63
#     weight = 0.1 / (|2 - 63| + 0.1) = 0.001637
#     term = 0.001637 * 4.3764901 = 0.007163
#   For i=2, j=25:
#     days_diff_i = 2, days_diff_j = 63
#     weight = 0.1 / (|2 - 63| + 0.1) = 0.001637
#     term = 0.001637 * 4.3764901 = 0.007163
#   For i=2, j=26:
#     days_diff_i = 2, days_diff_j = 63
#     weight = 0.1 / (|2 - 63| + 0.1) = 0.001637
#     term = 0.001637 * 4.3764901 = 0.007163
#   For i=2, j=27:
#     days_diff_i = 2, days_diff_j = 59
#     weight = 0.1 / (|2 - 59| + 0.1) = 0.001751
#     term = 0.001751 * 4.3764901 = 0.007665
#   For i=2, j=28:
#     days_diff_i = 2, days_diff_j = 61
#     weight = 0.1 / (|2 - 61| + 0.1) = 0.001692
#     term = 0.001692 * 4.3764901 = 0.007405
#
#   For i=2:
#     Sum of weights = 0.385564
#     Final result = 1.687035 / 0.385564 = 4.375494
#
#   For i=3, j=0:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.3473617 = 4.347362
#   For i=3, j=1:
#     days_diff_i = 1, days_diff_j = 1
#     weight = 0.1 / (|1 - 1| + 0.1) = 1.000000
#     term = 1.000000 * 4.3583495 = 4.358350
#   For i=3, j=2:
#     days_diff_i = 1, days_diff_j = 2
#     weight = 0.1 / (|1 - 2| + 0.1) = 0.090909
#     term = 0.090909 * 4.4000002 = 0.400000
#   For i=3, j=4:
#     days_diff_i = 1, days_diff_j = 6
#     weight = 0.1 / (|1 - 6| + 0.1) = 0.019608
#     term = 0.019608 * 4.3967164 = 0.086210
#   For i=3, j=5:
#     days_diff_i = 1, days_diff_j = 10
#     weight = 0.1 / (|1 - 10| + 0.1) = 0.010989
#     term = 0.010989 * 4.3799998 = 0.048132
#   For i=3, j=6:
#     days_diff_i = 1, days_diff_j = 13
#     weight = 0.1 / (|1 - 13| + 0.1) = 0.008264
#     term = 0.008264 * 4.4000002 = 0.036364
#   For i=3, j=7:
#     days_diff_i = 1, days_diff_j = 15
#     weight = 0.1 / (|1 - 15| + 0.1) = 0.007092
#     term = 0.007092 * 4.4100002 = 0.031277
#   For i=3, j=8:
#     days_diff_i = 1, days_diff_j = 14
#     weight = 0.1 / (|1 - 14| + 0.1) = 0.007634
#     term = 0.007634 * 4.4 = 0.033588
#   For i=3, j=9:
#     days_diff_i = 1, days_diff_j = 20
#     weight = 0.1 / (|1 - 20| + 0.1) = 0.005236
#     term = 0.005236 * 4.3912443 = 0.022991
#   For i=3, j=10:
#     days_diff_i = 1, days_diff_j = 21
#     weight = 0.1 / (|1 - 21| + 0.1) = 0.004975
#     term = 0.004975 * 4.3579999 = 0.021682
#   For i=3, j=11:
#     days_diff_i = 1, days_diff_j = 24
#     weight = 0.1 / (|1 - 24| + 0.1) = 0.004329
#     term = 0.004329 * 4.4 = 0.019048
#   For i=3, j=12:
#     days_diff_i = 1, days_diff_j = 23
#     weight = 0.1 / (|1 - 23| + 0.1) = 0.004525
#     term = 0.004525 * 4.3725001 = 0.019785
#   For i=3, j=13:
#     days_diff_i = 1, days_diff_j = 26
#     weight = 0.1 / (|1 - 26| + 0.1) = 0.003984
#     term = 0.003984 * 4.4187439 = 0.017605
#   For i=3, j=14:
#     days_diff_i = 1, days_diff_j = 30
#     weight = 0.1 / (|1 - 30| + 0.1) = 0.003436
#     term = 0.003436 * 4.4300001 = 0.015223
#   For i=3, j=15:
#     days_diff_i = 1, days_diff_j = 37
#     weight = 0.1 / (|1 - 37| + 0.1) = 0.002770
#     term = 0.002770 * 4.42 = 0.012244
#   For i=3, j=16:
#     days_diff_i = 1, days_diff_j = 100
#     weight = 0.1 / (|1 - 100| + 0.1) = 0.001009
#     term = 0.001009 * 4.3915022 = 0.004431
#   For i=3, j=17:
#     days_diff_i = 1, days_diff_j = 92
#     weight = 0.1 / (|1 - 92| + 0.1) = 0.001098
#     term = 0.001098 * 4.3764901 = 0.004804
#   For i=3, j=18:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=3, j=19:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=3, j=20:
#     days_diff_i = 1, days_diff_j = 64
#     weight = 0.1 / (|1 - 64| + 0.1) = 0.001585
#     term = 0.001585 * 4.3764901 = 0.006936
#   For i=3, j=21:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=3, j=22:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=3, j=23:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#   For i=3, j=24:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=3, j=25:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=3, j=26:
#     days_diff_i = 1, days_diff_j = 63
#     weight = 0.1 / (|1 - 63| + 0.1) = 0.001610
#     term = 0.001610 * 4.3764901 = 0.007047
#   For i=3, j=27:
#     days_diff_i = 1, days_diff_j = 59
#     weight = 0.1 / (|1 - 59| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=3, j=28:
#     days_diff_i = 1, days_diff_j = 61
#     weight = 0.1 / (|1 - 61| + 0.1) = 0.001664
#     term = 0.001664 * 4.3764901 = 0.007282
#
#   For i=3:
#     Sum of weights = 2.194036
#     Final result = 9.558647 / 2.194036 = 4.356651
#
#   For i=4, j=0:
#     days_diff_i = 6, days_diff_j = 1
#     weight = 0.1 / (|6 - 1| + 0.1) = 0.019608
#     term = 0.019608 * 4.3473617 = 0.085242
#   For i=4, j=1:
#     days_diff_i = 6, days_diff_j = 1
#     weight = 0.1 / (|6 - 1| + 0.1) = 0.019608
#     term = 0.019608 * 4.3583495 = 0.085458
#   For i=4, j=2:
#     days_diff_i = 6, days_diff_j = 2
#     weight = 0.1 / (|6 - 2| + 0.1) = 0.024390
#     term = 0.024390 * 4.4000002 = 0.107317
#   For i=4, j=3:
#     days_diff_i = 6, days_diff_j = 1
#     weight = 0.1 / (|6 - 1| + 0.1) = 0.019608
#     term = 0.019608 * 4.4000009 = 0.086275
#   For i=4, j=5:
#     days_diff_i = 6, days_diff_j = 10
#     weight = 0.1 / (|6 - 10| + 0.1) = 0.024390
#     term = 0.024390 * 4.3799998 = 0.106829
#   For i=4, j=6:
#     days_diff_i = 6, days_diff_j = 13
#     weight = 0.1 / (|6 - 13| + 0.1) = 0.014085
#     term = 0.014085 * 4.4000002 = 0.061972
#   For i=4, j=7:
#     days_diff_i = 6, days_diff_j = 15
#     weight = 0.1 / (|6 - 15| + 0.1) = 0.010989
#     term = 0.010989 * 4.4100002 = 0.048462
#   For i=4, j=8:
#     days_diff_i = 6, days_diff_j = 14
#     weight = 0.1 / (|6 - 14| + 0.1) = 0.012346
#     term = 0.012346 * 4.4 = 0.054321
#   For i=4, j=9:
#     days_diff_i = 6, days_diff_j = 20
#     weight = 0.1 / (|6 - 20| + 0.1) = 0.007092
#     term = 0.007092 * 4.3912443 = 0.031144
#   For i=4, j=10:
#     days_diff_i = 6, days_diff_j = 21
#     weight = 0.1 / (|6 - 21| + 0.1) = 0.006623
#     term = 0.006623 * 4.3579999 = 0.028861
#   For i=4, j=11:
#     days_diff_i = 6, days_diff_j = 24
#     weight = 0.1 / (|6 - 24| + 0.1) = 0.005525
#     term = 0.005525 * 4.4 = 0.024309
#   For i=4, j=12:
#     days_diff_i = 6, days_diff_j = 23
#     weight = 0.1 / (|6 - 23| + 0.1) = 0.005848
#     term = 0.005848 * 4.3725001 = 0.025570
#   For i=4, j=13:
#     days_diff_i = 6, days_diff_j = 26
#     weight = 0.1 / (|6 - 26| + 0.1) = 0.004975
#     term = 0.004975 * 4.4187439 = 0.021984
#   For i=4, j=14:
#     days_diff_i = 6, days_diff_j = 30
#     weight = 0.1 / (|6 - 30| + 0.1) = 0.004149
#     term = 0.004149 * 4.4300001 = 0.018382
#   For i=4, j=15:
#     days_diff_i = 6, days_diff_j = 37
#     weight = 0.1 / (|6 - 37| + 0.1) = 0.003215
#     term = 0.003215 * 4.42 = 0.014212
#   For i=4, j=16:
#     days_diff_i = 6, days_diff_j = 100
#     weight = 0.1 / (|6 - 100| + 0.1) = 0.001063
#     term = 0.001063 * 4.3915022 = 0.004667
#   For i=4, j=17:
#     days_diff_i = 6, days_diff_j = 92
#     weight = 0.1 / (|6 - 92| + 0.1) = 0.001161
#     term = 0.001161 * 4.3764901 = 0.005083
#   For i=4, j=18:
#     days_diff_i = 6, days_diff_j = 61
#     weight = 0.1 / (|6 - 61| + 0.1) = 0.001815
#     term = 0.001815 * 4.3764901 = 0.007943
#   For i=4, j=19:
#     days_diff_i = 6, days_diff_j = 61
#     weight = 0.1 / (|6 - 61| + 0.1) = 0.001815
#     term = 0.001815 * 4.3764901 = 0.007943
#   For i=4, j=20:
#     days_diff_i = 6, days_diff_j = 64
#     weight = 0.1 / (|6 - 64| + 0.1) = 0.001721
#     term = 0.001721 * 4.3764901 = 0.007533
#   For i=4, j=21:
#     days_diff_i = 6, days_diff_j = 59
#     weight = 0.1 / (|6 - 59| + 0.1) = 0.001883
#     term = 0.001883 * 4.3764901 = 0.008242
#   For i=4, j=22:
#     days_diff_i = 6, days_diff_j = 61
#     weight = 0.1 / (|6 - 61| + 0.1) = 0.001815
#     term = 0.001815 * 4.3764901 = 0.007943
#   For i=4, j=23:
#     days_diff_i = 6, days_diff_j = 61
#     weight = 0.1 / (|6 - 61| + 0.1) = 0.001815
#     term = 0.001815 * 4.3764901 = 0.007943
#   For i=4, j=24:
#     days_diff_i = 6, days_diff_j = 63
#     weight = 0.1 / (|6 - 63| + 0.1) = 0.001751
#     term = 0.001751 * 4.3764901 = 0.007665
#   For i=4, j=25:
#     days_diff_i = 6, days_diff_j = 63
#     weight = 0.1 / (|6 - 63| + 0.1) = 0.001751
#     term = 0.001751 * 4.3764901 = 0.007665
#   For i=4, j=26:
#     days_diff_i = 6, days_diff_j = 63
#     weight = 0.1 / (|6 - 63| + 0.1) = 0.001751
#     term = 0.001751 * 4.3764901 = 0.007665
#   For i=4, j=27:
#     days_diff_i = 6, days_diff_j = 59
#     weight = 0.1 / (|6 - 59| + 0.1) = 0.001883
#     term = 0.001883 * 4.3764901 = 0.008242
#   For i=4, j=28:
#     days_diff_i = 6, days_diff_j = 61
#     weight = 0.1 / (|6 - 61| + 0.1) = 0.001815
#     term = 0.001815 * 4.3764901 = 0.007943
#
#   For i=4:
#     Sum of weights = 0.204491
#     Final result = 0.896812 / 0.204491 = 4.385584
#
#   For i=5, j=0:
#     days_diff_i = 10, days_diff_j = 1
#     weight = 0.1 / (|10 - 1| + 0.1) = 0.010989
#     term = 0.010989 * 4.3473617 = 0.047773
#   For i=5, j=1:
#     days_diff_i = 10, days_diff_j = 1
#     weight = 0.1 / (|10 - 1| + 0.1) = 0.010989
#     term = 0.010989 * 4.3583495 = 0.047894
#   For i=5, j=2:
#     days_diff_i = 10, days_diff_j = 2
#     weight = 0.1 / (|10 - 2| + 0.1) = 0.012346
#     term = 0.012346 * 4.4000002 = 0.054321
#   For i=5, j=3:
#     days_diff_i = 10, days_diff_j = 1
#     weight = 0.1 / (|10 - 1| + 0.1) = 0.010989
#     term = 0.010989 * 4.4000009 = 0.048352
#   For i=5, j=4:
#     days_diff_i = 10, days_diff_j = 6
#     weight = 0.1 / (|10 - 6| + 0.1) = 0.024390
#     term = 0.024390 * 4.3967164 = 0.107237
#   For i=5, j=6:
#     days_diff_i = 10, days_diff_j = 13
#     weight = 0.1 / (|10 - 13| + 0.1) = 0.032258
#     term = 0.032258 * 4.4000002 = 0.141935
#   For i=5, j=7:
#     days_diff_i = 10, days_diff_j = 15
#     weight = 0.1 / (|10 - 15| + 0.1) = 0.019608
#     term = 0.019608 * 4.4100002 = 0.086471
#   For i=5, j=8:
#     days_diff_i = 10, days_diff_j = 14
#     weight = 0.1 / (|10 - 14| + 0.1) = 0.024390
#     term = 0.024390 * 4.4 = 0.107317
#   For i=5, j=9:
#     days_diff_i = 10, days_diff_j = 20
#     weight = 0.1 / (|10 - 20| + 0.1) = 0.009901
#     term = 0.009901 * 4.3912443 = 0.043478
#   For i=5, j=10:
#     days_diff_i = 10, days_diff_j = 21
#     weight = 0.1 / (|10 - 21| + 0.1) = 0.009009
#     term = 0.009009 * 4.3579999 = 0.039261
#   For i=5, j=11:
#     days_diff_i = 10, days_diff_j = 24
#     weight = 0.1 / (|10 - 24| + 0.1) = 0.007092
#     term = 0.007092 * 4.4 = 0.031206
#   For i=5, j=12:
#     days_diff_i = 10, days_diff_j = 23
#     weight = 0.1 / (|10 - 23| + 0.1) = 0.007634
#     term = 0.007634 * 4.3725001 = 0.033378
#   For i=5, j=13:
#     days_diff_i = 10, days_diff_j = 26
#     weight = 0.1 / (|10 - 26| + 0.1) = 0.006211
#     term = 0.006211 * 4.4187439 = 0.027446
#   For i=5, j=14:
#     days_diff_i = 10, days_diff_j = 30
#     weight = 0.1 / (|10 - 30| + 0.1) = 0.004975
#     term = 0.004975 * 4.4300001 = 0.022040
#   For i=5, j=15:
#     days_diff_i = 10, days_diff_j = 37
#     weight = 0.1 / (|10 - 37| + 0.1) = 0.003690
#     term = 0.003690 * 4.42 = 0.016310
#   For i=5, j=16:
#     days_diff_i = 10, days_diff_j = 100
#     weight = 0.1 / (|10 - 100| + 0.1) = 0.001110
#     term = 0.001110 * 4.3915022 = 0.004874
#   For i=5, j=17:
#     days_diff_i = 10, days_diff_j = 92
#     weight = 0.1 / (|10 - 92| + 0.1) = 0.001218
#     term = 0.001218 * 4.3764901 = 0.005331
#   For i=5, j=18:
#     days_diff_i = 10, days_diff_j = 61
#     weight = 0.1 / (|10 - 61| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#   For i=5, j=19:
#     days_diff_i = 10, days_diff_j = 61
#     weight = 0.1 / (|10 - 61| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#   For i=5, j=20:
#     days_diff_i = 10, days_diff_j = 64
#     weight = 0.1 / (|10 - 64| + 0.1) = 0.001848
#     term = 0.001848 * 4.3764901 = 0.008090
#   For i=5, j=21:
#     days_diff_i = 10, days_diff_j = 59
#     weight = 0.1 / (|10 - 59| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=5, j=22:
#     days_diff_i = 10, days_diff_j = 61
#     weight = 0.1 / (|10 - 61| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#   For i=5, j=23:
#     days_diff_i = 10, days_diff_j = 61
#     weight = 0.1 / (|10 - 61| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#   For i=5, j=24:
#     days_diff_i = 10, days_diff_j = 63
#     weight = 0.1 / (|10 - 63| + 0.1) = 0.001883
#     term = 0.001883 * 4.3764901 = 0.008242
#   For i=5, j=25:
#     days_diff_i = 10, days_diff_j = 63
#     weight = 0.1 / (|10 - 63| + 0.1) = 0.001883
#     term = 0.001883 * 4.3764901 = 0.008242
#   For i=5, j=26:
#     days_diff_i = 10, days_diff_j = 63
#     weight = 0.1 / (|10 - 63| + 0.1) = 0.001883
#     term = 0.001883 * 4.3764901 = 0.008242
#   For i=5, j=27:
#     days_diff_i = 10, days_diff_j = 59
#     weight = 0.1 / (|10 - 59| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=5, j=28:
#     days_diff_i = 10, days_diff_j = 61
#     weight = 0.1 / (|10 - 61| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#
#   For i=5:
#     Sum of weights = 0.218155
#     Final result = 0.958088 / 0.218155 = 4.391768
#
#   For i=6, j=0:
#     days_diff_i = 13, days_diff_j = 1
#     weight = 0.1 / (|13 - 1| + 0.1) = 0.008264
#     term = 0.008264 * 4.3473617 = 0.035929
#   For i=6, j=1:
#     days_diff_i = 13, days_diff_j = 1
#     weight = 0.1 / (|13 - 1| + 0.1) = 0.008264
#     term = 0.008264 * 4.3583495 = 0.036019
#   For i=6, j=2:
#     days_diff_i = 13, days_diff_j = 2
#     weight = 0.1 / (|13 - 2| + 0.1) = 0.009009
#     term = 0.009009 * 4.4000002 = 0.039640
#   For i=6, j=3:
#     days_diff_i = 13, days_diff_j = 1
#     weight = 0.1 / (|13 - 1| + 0.1) = 0.008264
#     term = 0.008264 * 4.4000009 = 0.036364
#   For i=6, j=4:
#     days_diff_i = 13, days_diff_j = 6
#     weight = 0.1 / (|13 - 6| + 0.1) = 0.014085
#     term = 0.014085 * 4.3967164 = 0.061926
#   For i=6, j=5:
#     days_diff_i = 13, days_diff_j = 10
#     weight = 0.1 / (|13 - 10| + 0.1) = 0.032258
#     term = 0.032258 * 4.3799998 = 0.141290
#   For i=6, j=7:
#     days_diff_i = 13, days_diff_j = 15
#     weight = 0.1 / (|13 - 15| + 0.1) = 0.047619
#     term = 0.047619 * 4.4100002 = 0.210000
#   For i=6, j=8:
#     days_diff_i = 13, days_diff_j = 14
#     weight = 0.1 / (|13 - 14| + 0.1) = 0.090909
#     term = 0.090909 * 4.4 = 0.400000
#   For i=6, j=9:
#     days_diff_i = 13, days_diff_j = 20
#     weight = 0.1 / (|13 - 20| + 0.1) = 0.014085
#     term = 0.014085 * 4.3912443 = 0.061849
#   For i=6, j=10:
#     days_diff_i = 13, days_diff_j = 21
#     weight = 0.1 / (|13 - 21| + 0.1) = 0.012346
#     term = 0.012346 * 4.3579999 = 0.053802
#   For i=6, j=11:
#     days_diff_i = 13, days_diff_j = 24
#     weight = 0.1 / (|13 - 24| + 0.1) = 0.009009
#     term = 0.009009 * 4.4 = 0.039640
#   For i=6, j=12:
#     days_diff_i = 13, days_diff_j = 23
#     weight = 0.1 / (|13 - 23| + 0.1) = 0.009901
#     term = 0.009901 * 4.3725001 = 0.043292
#   For i=6, j=13:
#     days_diff_i = 13, days_diff_j = 26
#     weight = 0.1 / (|13 - 26| + 0.1) = 0.007634
#     term = 0.007634 * 4.4187439 = 0.033731
#   For i=6, j=14:
#     days_diff_i = 13, days_diff_j = 30
#     weight = 0.1 / (|13 - 30| + 0.1) = 0.005848
#     term = 0.005848 * 4.4300001 = 0.025906
#   For i=6, j=15:
#     days_diff_i = 13, days_diff_j = 37
#     weight = 0.1 / (|13 - 37| + 0.1) = 0.004149
#     term = 0.004149 * 4.42 = 0.018340
#   For i=6, j=16:
#     days_diff_i = 13, days_diff_j = 100
#     weight = 0.1 / (|13 - 100| + 0.1) = 0.001148
#     term = 0.001148 * 4.3915022 = 0.005042
#   For i=6, j=17:
#     days_diff_i = 13, days_diff_j = 92
#     weight = 0.1 / (|13 - 92| + 0.1) = 0.001264
#     term = 0.001264 * 4.3764901 = 0.005533
#   For i=6, j=18:
#     days_diff_i = 13, days_diff_j = 61
#     weight = 0.1 / (|13 - 61| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=6, j=19:
#     days_diff_i = 13, days_diff_j = 61
#     weight = 0.1 / (|13 - 61| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=6, j=20:
#     days_diff_i = 13, days_diff_j = 64
#     weight = 0.1 / (|13 - 64| + 0.1) = 0.001957
#     term = 0.001957 * 4.3764901 = 0.008565
#   For i=6, j=21:
#     days_diff_i = 13, days_diff_j = 59
#     weight = 0.1 / (|13 - 59| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=6, j=22:
#     days_diff_i = 13, days_diff_j = 61
#     weight = 0.1 / (|13 - 61| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=6, j=23:
#     days_diff_i = 13, days_diff_j = 61
#     weight = 0.1 / (|13 - 61| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=6, j=24:
#     days_diff_i = 13, days_diff_j = 63
#     weight = 0.1 / (|13 - 63| + 0.1) = 0.001996
#     term = 0.001996 * 4.3764901 = 0.008736
#   For i=6, j=25:
#     days_diff_i = 13, days_diff_j = 63
#     weight = 0.1 / (|13 - 63| + 0.1) = 0.001996
#     term = 0.001996 * 4.3764901 = 0.008736
#   For i=6, j=26:
#     days_diff_i = 13, days_diff_j = 63
#     weight = 0.1 / (|13 - 63| + 0.1) = 0.001996
#     term = 0.001996 * 4.3764901 = 0.008736
#   For i=6, j=27:
#     days_diff_i = 13, days_diff_j = 59
#     weight = 0.1 / (|13 - 59| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=6, j=28:
#     days_diff_i = 13, days_diff_j = 61
#     weight = 0.1 / (|13 - 61| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#
#   For i=6:
#     Sum of weights = 0.306735
#     Final result = 1.347554 / 0.306735 = 4.393220
#
#   For i=7, j=0:
#     days_diff_i = 15, days_diff_j = 1
#     weight = 0.1 / (|15 - 1| + 0.1) = 0.007092
#     term = 0.007092 * 4.3473617 = 0.030832
#   For i=7, j=1:
#     days_diff_i = 15, days_diff_j = 1
#     weight = 0.1 / (|15 - 1| + 0.1) = 0.007092
#     term = 0.007092 * 4.3583495 = 0.030910
#   For i=7, j=2:
#     days_diff_i = 15, days_diff_j = 2
#     weight = 0.1 / (|15 - 2| + 0.1) = 0.007634
#     term = 0.007634 * 4.4000002 = 0.033588
#   For i=7, j=3:
#     days_diff_i = 15, days_diff_j = 1
#     weight = 0.1 / (|15 - 1| + 0.1) = 0.007092
#     term = 0.007092 * 4.4000009 = 0.031206
#   For i=7, j=4:
#     days_diff_i = 15, days_diff_j = 6
#     weight = 0.1 / (|15 - 6| + 0.1) = 0.010989
#     term = 0.010989 * 4.3967164 = 0.048316
#   For i=7, j=5:
#     days_diff_i = 15, days_diff_j = 10
#     weight = 0.1 / (|15 - 10| + 0.1) = 0.019608
#     term = 0.019608 * 4.3799998 = 0.085882
#   For i=7, j=6:
#     days_diff_i = 15, days_diff_j = 13
#     weight = 0.1 / (|15 - 13| + 0.1) = 0.047619
#     term = 0.047619 * 4.4000002 = 0.209524
#   For i=7, j=8:
#     days_diff_i = 15, days_diff_j = 14
#     weight = 0.1 / (|15 - 14| + 0.1) = 0.090909
#     term = 0.090909 * 4.4 = 0.400000
#   For i=7, j=9:
#     days_diff_i = 15, days_diff_j = 20
#     weight = 0.1 / (|15 - 20| + 0.1) = 0.019608
#     term = 0.019608 * 4.3912443 = 0.086103
#   For i=7, j=10:
#     days_diff_i = 15, days_diff_j = 21
#     weight = 0.1 / (|15 - 21| + 0.1) = 0.016393
#     term = 0.016393 * 4.3579999 = 0.071443
#   For i=7, j=11:
#     days_diff_i = 15, days_diff_j = 24
#     weight = 0.1 / (|15 - 24| + 0.1) = 0.010989
#     term = 0.010989 * 4.4 = 0.048352
#   For i=7, j=12:
#     days_diff_i = 15, days_diff_j = 23
#     weight = 0.1 / (|15 - 23| + 0.1) = 0.012346
#     term = 0.012346 * 4.3725001 = 0.053981
#   For i=7, j=13:
#     days_diff_i = 15, days_diff_j = 26
#     weight = 0.1 / (|15 - 26| + 0.1) = 0.009009
#     term = 0.009009 * 4.4187439 = 0.039809
#   For i=7, j=14:
#     days_diff_i = 15, days_diff_j = 30
#     weight = 0.1 / (|15 - 30| + 0.1) = 0.006623
#     term = 0.006623 * 4.4300001 = 0.029338
#   For i=7, j=15:
#     days_diff_i = 15, days_diff_j = 37
#     weight = 0.1 / (|15 - 37| + 0.1) = 0.004525
#     term = 0.004525 * 4.42 = 0.020000
#   For i=7, j=16:
#     days_diff_i = 15, days_diff_j = 100
#     weight = 0.1 / (|15 - 100| + 0.1) = 0.001175
#     term = 0.001175 * 4.3915022 = 0.005160
#   For i=7, j=17:
#     days_diff_i = 15, days_diff_j = 92
#     weight = 0.1 / (|15 - 92| + 0.1) = 0.001297
#     term = 0.001297 * 4.3764901 = 0.005676
#   For i=7, j=18:
#     days_diff_i = 15, days_diff_j = 61
#     weight = 0.1 / (|15 - 61| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=7, j=19:
#     days_diff_i = 15, days_diff_j = 61
#     weight = 0.1 / (|15 - 61| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=7, j=20:
#     days_diff_i = 15, days_diff_j = 64
#     weight = 0.1 / (|15 - 64| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=7, j=21:
#     days_diff_i = 15, days_diff_j = 59
#     weight = 0.1 / (|15 - 59| + 0.1) = 0.002268
#     term = 0.002268 * 4.3764901 = 0.009924
#   For i=7, j=22:
#     days_diff_i = 15, days_diff_j = 61
#     weight = 0.1 / (|15 - 61| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=7, j=23:
#     days_diff_i = 15, days_diff_j = 61
#     weight = 0.1 / (|15 - 61| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#   For i=7, j=24:
#     days_diff_i = 15, days_diff_j = 63
#     weight = 0.1 / (|15 - 63| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=7, j=25:
#     days_diff_i = 15, days_diff_j = 63
#     weight = 0.1 / (|15 - 63| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=7, j=26:
#     days_diff_i = 15, days_diff_j = 63
#     weight = 0.1 / (|15 - 63| + 0.1) = 0.002079
#     term = 0.002079 * 4.3764901 = 0.009099
#   For i=7, j=27:
#     days_diff_i = 15, days_diff_j = 59
#     weight = 0.1 / (|15 - 59| + 0.1) = 0.002268
#     term = 0.002268 * 4.3764901 = 0.009924
#   For i=7, j=28:
#     days_diff_i = 15, days_diff_j = 61
#     weight = 0.1 / (|15 - 61| + 0.1) = 0.002169
#     term = 0.002169 * 4.3764901 = 0.009493
#
#   For i=7:
#     Sum of weights = 0.303654
#     Final result = 1.333644 / 0.303654 = 4.391980
#
#   For i=8, j=0:
#     days_diff_i = 14, days_diff_j = 1
#     weight = 0.1 / (|14 - 1| + 0.1) = 0.007634
#     term = 0.007634 * 4.3473617 = 0.033186
#   For i=8, j=1:
#     days_diff_i = 14, days_diff_j = 1
#     weight = 0.1 / (|14 - 1| + 0.1) = 0.007634
#     term = 0.007634 * 4.3583495 = 0.033270
#   For i=8, j=2:
#     days_diff_i = 14, days_diff_j = 2
#     weight = 0.1 / (|14 - 2| + 0.1) = 0.008264
#     term = 0.008264 * 4.4000002 = 0.036364
#   For i=8, j=3:
#     days_diff_i = 14, days_diff_j = 1
#     weight = 0.1 / (|14 - 1| + 0.1) = 0.007634
#     term = 0.007634 * 4.4000009 = 0.033588
#   For i=8, j=4:
#     days_diff_i = 14, days_diff_j = 6
#     weight = 0.1 / (|14 - 6| + 0.1) = 0.012346
#     term = 0.012346 * 4.3967164 = 0.054280
#   For i=8, j=5:
#     days_diff_i = 14, days_diff_j = 10
#     weight = 0.1 / (|14 - 10| + 0.1) = 0.024390
#     term = 0.024390 * 4.3799998 = 0.106829
#   For i=8, j=6:
#     days_diff_i = 14, days_diff_j = 13
#     weight = 0.1 / (|14 - 13| + 0.1) = 0.090909
#     term = 0.090909 * 4.4000002 = 0.400000
#   For i=8, j=7:
#     days_diff_i = 14, days_diff_j = 15
#     weight = 0.1 / (|14 - 15| + 0.1) = 0.090909
#     term = 0.090909 * 4.4100002 = 0.400909
#   For i=8, j=9:
#     days_diff_i = 14, days_diff_j = 20
#     weight = 0.1 / (|14 - 20| + 0.1) = 0.016393
#     term = 0.016393 * 4.3912443 = 0.071988
#   For i=8, j=10:
#     days_diff_i = 14, days_diff_j = 21
#     weight = 0.1 / (|14 - 21| + 0.1) = 0.014085
#     term = 0.014085 * 4.3579999 = 0.061380
#   For i=8, j=11:
#     days_diff_i = 14, days_diff_j = 24
#     weight = 0.1 / (|14 - 24| + 0.1) = 0.009901
#     term = 0.009901 * 4.4 = 0.043564
#   For i=8, j=12:
#     days_diff_i = 14, days_diff_j = 23
#     weight = 0.1 / (|14 - 23| + 0.1) = 0.010989
#     term = 0.010989 * 4.3725001 = 0.048049
#   For i=8, j=13:
#     days_diff_i = 14, days_diff_j = 26
#     weight = 0.1 / (|14 - 26| + 0.1) = 0.008264
#     term = 0.008264 * 4.4187439 = 0.036519
#   For i=8, j=14:
#     days_diff_i = 14, days_diff_j = 30
#     weight = 0.1 / (|14 - 30| + 0.1) = 0.006211
#     term = 0.006211 * 4.4300001 = 0.027516
#   For i=8, j=15:
#     days_diff_i = 14, days_diff_j = 37
#     weight = 0.1 / (|14 - 37| + 0.1) = 0.004329
#     term = 0.004329 * 4.42 = 0.019134
#   For i=8, j=16:
#     days_diff_i = 14, days_diff_j = 100
#     weight = 0.1 / (|14 - 100| + 0.1) = 0.001161
#     term = 0.001161 * 4.3915022 = 0.005100
#   For i=8, j=17:
#     days_diff_i = 14, days_diff_j = 92
#     weight = 0.1 / (|14 - 92| + 0.1) = 0.001280
#     term = 0.001280 * 4.3764901 = 0.005604
#   For i=8, j=18:
#     days_diff_i = 14, days_diff_j = 61
#     weight = 0.1 / (|14 - 61| + 0.1) = 0.002123
#     term = 0.002123 * 4.3764901 = 0.009292
#   For i=8, j=19:
#     days_diff_i = 14, days_diff_j = 61
#     weight = 0.1 / (|14 - 61| + 0.1) = 0.002123
#     term = 0.002123 * 4.3764901 = 0.009292
#   For i=8, j=20:
#     days_diff_i = 14, days_diff_j = 64
#     weight = 0.1 / (|14 - 64| + 0.1) = 0.001996
#     term = 0.001996 * 4.3764901 = 0.008736
#   For i=8, j=21:
#     days_diff_i = 14, days_diff_j = 59
#     weight = 0.1 / (|14 - 59| + 0.1) = 0.002217
#     term = 0.002217 * 4.3764901 = 0.009704
#   For i=8, j=22:
#     days_diff_i = 14, days_diff_j = 61
#     weight = 0.1 / (|14 - 61| + 0.1) = 0.002123
#     term = 0.002123 * 4.3764901 = 0.009292
#   For i=8, j=23:
#     days_diff_i = 14, days_diff_j = 61
#     weight = 0.1 / (|14 - 61| + 0.1) = 0.002123
#     term = 0.002123 * 4.3764901 = 0.009292
#   For i=8, j=24:
#     days_diff_i = 14, days_diff_j = 63
#     weight = 0.1 / (|14 - 63| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=8, j=25:
#     days_diff_i = 14, days_diff_j = 63
#     weight = 0.1 / (|14 - 63| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=8, j=26:
#     days_diff_i = 14, days_diff_j = 63
#     weight = 0.1 / (|14 - 63| + 0.1) = 0.002037
#     term = 0.002037 * 4.3764901 = 0.008913
#   For i=8, j=27:
#     days_diff_i = 14, days_diff_j = 59
#     weight = 0.1 / (|14 - 59| + 0.1) = 0.002217
#     term = 0.002217 * 4.3764901 = 0.009704
#   For i=8, j=28:
#     days_diff_i = 14, days_diff_j = 61
#     weight = 0.1 / (|14 - 61| + 0.1) = 0.002123
#     term = 0.002123 * 4.3764901 = 0.009292
#
#   For i=8:
#     Sum of weights = 0.345490
#     Final result = 1.518623 / 0.345490 = 4.395563
#
#   For i=9, j=0:
#     days_diff_i = 20, days_diff_j = 1
#     weight = 0.1 / (|20 - 1| + 0.1) = 0.005236
#     term = 0.005236 * 4.3473617 = 0.022761
#   For i=9, j=1:
#     days_diff_i = 20, days_diff_j = 1
#     weight = 0.1 / (|20 - 1| + 0.1) = 0.005236
#     term = 0.005236 * 4.3583495 = 0.022819
#   For i=9, j=2:
#     days_diff_i = 20, days_diff_j = 2
#     weight = 0.1 / (|20 - 2| + 0.1) = 0.005525
#     term = 0.005525 * 4.4000002 = 0.024309
#   For i=9, j=3:
#     days_diff_i = 20, days_diff_j = 1
#     weight = 0.1 / (|20 - 1| + 0.1) = 0.005236
#     term = 0.005236 * 4.4000009 = 0.023037
#   For i=9, j=4:
#     days_diff_i = 20, days_diff_j = 6
#     weight = 0.1 / (|20 - 6| + 0.1) = 0.007092
#     term = 0.007092 * 4.3967164 = 0.031182
#   For i=9, j=5:
#     days_diff_i = 20, days_diff_j = 10
#     weight = 0.1 / (|20 - 10| + 0.1) = 0.009901
#     term = 0.009901 * 4.3799998 = 0.043366
#   For i=9, j=6:
#     days_diff_i = 20, days_diff_j = 13
#     weight = 0.1 / (|20 - 13| + 0.1) = 0.014085
#     term = 0.014085 * 4.4000002 = 0.061972
#   For i=9, j=7:
#     days_diff_i = 20, days_diff_j = 15
#     weight = 0.1 / (|20 - 15| + 0.1) = 0.019608
#     term = 0.019608 * 4.4100002 = 0.086471
#   For i=9, j=8:
#     days_diff_i = 20, days_diff_j = 14
#     weight = 0.1 / (|20 - 14| + 0.1) = 0.016393
#     term = 0.016393 * 4.4 = 0.072131
#   For i=9, j=10:
#     days_diff_i = 20, days_diff_j = 21
#     weight = 0.1 / (|20 - 21| + 0.1) = 0.090909
#     term = 0.090909 * 4.3579999 = 0.396182
#   For i=9, j=11:
#     days_diff_i = 20, days_diff_j = 24
#     weight = 0.1 / (|20 - 24| + 0.1) = 0.024390
#     term = 0.024390 * 4.4 = 0.107317
#   For i=9, j=12:
#     days_diff_i = 20, days_diff_j = 23
#     weight = 0.1 / (|20 - 23| + 0.1) = 0.032258
#     term = 0.032258 * 4.3725001 = 0.141048
#   For i=9, j=13:
#     days_diff_i = 20, days_diff_j = 26
#     weight = 0.1 / (|20 - 26| + 0.1) = 0.016393
#     term = 0.016393 * 4.4187439 = 0.072438
#   For i=9, j=14:
#     days_diff_i = 20, days_diff_j = 30
#     weight = 0.1 / (|20 - 30| + 0.1) = 0.009901
#     term = 0.009901 * 4.4300001 = 0.043861
#   For i=9, j=15:
#     days_diff_i = 20, days_diff_j = 37
#     weight = 0.1 / (|20 - 37| + 0.1) = 0.005848
#     term = 0.005848 * 4.42 = 0.025848
#   For i=9, j=16:
#     days_diff_i = 20, days_diff_j = 100
#     weight = 0.1 / (|20 - 100| + 0.1) = 0.001248
#     term = 0.001248 * 4.3915022 = 0.005483
#   For i=9, j=17:
#     days_diff_i = 20, days_diff_j = 92
#     weight = 0.1 / (|20 - 92| + 0.1) = 0.001387
#     term = 0.001387 * 4.3764901 = 0.006070
#   For i=9, j=18:
#     days_diff_i = 20, days_diff_j = 61
#     weight = 0.1 / (|20 - 61| + 0.1) = 0.002433
#     term = 0.002433 * 4.3764901 = 0.010648
#   For i=9, j=19:
#     days_diff_i = 20, days_diff_j = 61
#     weight = 0.1 / (|20 - 61| + 0.1) = 0.002433
#     term = 0.002433 * 4.3764901 = 0.010648
#   For i=9, j=20:
#     days_diff_i = 20, days_diff_j = 64
#     weight = 0.1 / (|20 - 64| + 0.1) = 0.002268
#     term = 0.002268 * 4.3764901 = 0.009924
#   For i=9, j=21:
#     days_diff_i = 20, days_diff_j = 59
#     weight = 0.1 / (|20 - 59| + 0.1) = 0.002558
#     term = 0.002558 * 4.3764901 = 0.011193
#   For i=9, j=22:
#     days_diff_i = 20, days_diff_j = 61
#     weight = 0.1 / (|20 - 61| + 0.1) = 0.002433
#     term = 0.002433 * 4.3764901 = 0.010648
#   For i=9, j=23:
#     days_diff_i = 20, days_diff_j = 61
#     weight = 0.1 / (|20 - 61| + 0.1) = 0.002433
#     term = 0.002433 * 4.3764901 = 0.010648
#   For i=9, j=24:
#     days_diff_i = 20, days_diff_j = 63
#     weight = 0.1 / (|20 - 63| + 0.1) = 0.002320
#     term = 0.002320 * 4.3764901 = 0.010154
#   For i=9, j=25:
#     days_diff_i = 20, days_diff_j = 63
#     weight = 0.1 / (|20 - 63| + 0.1) = 0.002320
#     term = 0.002320 * 4.3764901 = 0.010154
#   For i=9, j=26:
#     days_diff_i = 20, days_diff_j = 63
#     weight = 0.1 / (|20 - 63| + 0.1) = 0.002320
#     term = 0.002320 * 4.3764901 = 0.010154
#   For i=9, j=27:
#     days_diff_i = 20, days_diff_j = 59
#     weight = 0.1 / (|20 - 59| + 0.1) = 0.002558
#     term = 0.002558 * 4.3764901 = 0.011193
#   For i=9, j=28:
#     days_diff_i = 20, days_diff_j = 61
#     weight = 0.1 / (|20 - 61| + 0.1) = 0.002433
#     term = 0.002433 * 4.3764901 = 0.010648
#
#   For i=9:
#     Sum of weights = 0.297155
#     Final result = 1.302311 / 0.297155 = 4.382604
#
#   For i=10, j=0:
#     days_diff_i = 21, days_diff_j = 1
#     weight = 0.1 / (|21 - 1| + 0.1) = 0.004975
#     term = 0.004975 * 4.3473617 = 0.021629
#   For i=10, j=1:
#     days_diff_i = 21, days_diff_j = 1
#     weight = 0.1 / (|21 - 1| + 0.1) = 0.004975
#     term = 0.004975 * 4.3583495 = 0.021683
#   For i=10, j=2:
#     days_diff_i = 21, days_diff_j = 2
#     weight = 0.1 / (|21 - 2| + 0.1) = 0.005236
#     term = 0.005236 * 4.4000002 = 0.023037
#   For i=10, j=3:
#     days_diff_i = 21, days_diff_j = 1
#     weight = 0.1 / (|21 - 1| + 0.1) = 0.004975
#     term = 0.004975 * 4.4000009 = 0.021891
#   For i=10, j=4:
#     days_diff_i = 21, days_diff_j = 6
#     weight = 0.1 / (|21 - 6| + 0.1) = 0.006623
#     term = 0.006623 * 4.3967164 = 0.029117
#   For i=10, j=5:
#     days_diff_i = 21, days_diff_j = 10
#     weight = 0.1 / (|21 - 10| + 0.1) = 0.009009
#     term = 0.009009 * 4.3799998 = 0.039459
#   For i=10, j=6:
#     days_diff_i = 21, days_diff_j = 13
#     weight = 0.1 / (|21 - 13| + 0.1) = 0.012346
#     term = 0.012346 * 4.4000002 = 0.054321
#   For i=10, j=7:
#     days_diff_i = 21, days_diff_j = 15
#     weight = 0.1 / (|21 - 15| + 0.1) = 0.016393
#     term = 0.016393 * 4.4100002 = 0.072295
#   For i=10, j=8:
#     days_diff_i = 21, days_diff_j = 14
#     weight = 0.1 / (|21 - 14| + 0.1) = 0.014085
#     term = 0.014085 * 4.4 = 0.061972
#   For i=10, j=9:
#     days_diff_i = 21, days_diff_j = 20
#     weight = 0.1 / (|21 - 20| + 0.1) = 0.090909
#     term = 0.090909 * 4.3912443 = 0.399204
#   For i=10, j=11:
#     days_diff_i = 21, days_diff_j = 24
#     weight = 0.1 / (|21 - 24| + 0.1) = 0.032258
#     term = 0.032258 * 4.4 = 0.141935
#   For i=10, j=12:
#     days_diff_i = 21, days_diff_j = 23
#     weight = 0.1 / (|21 - 23| + 0.1) = 0.047619
#     term = 0.047619 * 4.3725001 = 0.208214
#   For i=10, j=13:
#     days_diff_i = 21, days_diff_j = 26
#     weight = 0.1 / (|21 - 26| + 0.1) = 0.019608
#     term = 0.019608 * 4.4187439 = 0.086642
#   For i=10, j=14:
#     days_diff_i = 21, days_diff_j = 30
#     weight = 0.1 / (|21 - 30| + 0.1) = 0.010989
#     term = 0.010989 * 4.4300001 = 0.048681
#   For i=10, j=15:
#     days_diff_i = 21, days_diff_j = 37
#     weight = 0.1 / (|21 - 37| + 0.1) = 0.006211
#     term = 0.006211 * 4.42 = 0.027453
#   For i=10, j=16:
#     days_diff_i = 21, days_diff_j = 100
#     weight = 0.1 / (|21 - 100| + 0.1) = 0.001264
#     term = 0.001264 * 4.3915022 = 0.005552
#   For i=10, j=17:
#     days_diff_i = 21, days_diff_j = 92
#     weight = 0.1 / (|21 - 92| + 0.1) = 0.001406
#     term = 0.001406 * 4.3764901 = 0.006155
#   For i=10, j=18:
#     days_diff_i = 21, days_diff_j = 61
#     weight = 0.1 / (|21 - 61| + 0.1) = 0.002494
#     term = 0.002494 * 4.3764901 = 0.010914
#   For i=10, j=19:
#     days_diff_i = 21, days_diff_j = 61
#     weight = 0.1 / (|21 - 61| + 0.1) = 0.002494
#     term = 0.002494 * 4.3764901 = 0.010914
#   For i=10, j=20:
#     days_diff_i = 21, days_diff_j = 64
#     weight = 0.1 / (|21 - 64| + 0.1) = 0.002320
#     term = 0.002320 * 4.3764901 = 0.010154
#   For i=10, j=21:
#     days_diff_i = 21, days_diff_j = 59
#     weight = 0.1 / (|21 - 59| + 0.1) = 0.002625
#     term = 0.002625 * 4.3764901 = 0.011487
#   For i=10, j=22:
#     days_diff_i = 21, days_diff_j = 61
#     weight = 0.1 / (|21 - 61| + 0.1) = 0.002494
#     term = 0.002494 * 4.3764901 = 0.010914
#   For i=10, j=23:
#     days_diff_i = 21, days_diff_j = 61
#     weight = 0.1 / (|21 - 61| + 0.1) = 0.002494
#     term = 0.002494 * 4.3764901 = 0.010914
#   For i=10, j=24:
#     days_diff_i = 21, days_diff_j = 63
#     weight = 0.1 / (|21 - 63| + 0.1) = 0.002375
#     term = 0.002375 * 4.3764901 = 0.010395
#   For i=10, j=25:
#     days_diff_i = 21, days_diff_j = 63
#     weight = 0.1 / (|21 - 63| + 0.1) = 0.002375
#     term = 0.002375 * 4.3764901 = 0.010395
#   For i=10, j=26:
#     days_diff_i = 21, days_diff_j = 63
#     weight = 0.1 / (|21 - 63| + 0.1) = 0.002375
#     term = 0.002375 * 4.3764901 = 0.010395
#   For i=10, j=27:
#     days_diff_i = 21, days_diff_j = 59
#     weight = 0.1 / (|21 - 59| + 0.1) = 0.002625
#     term = 0.002625 * 4.3764901 = 0.011487
#   For i=10, j=28:
#     days_diff_i = 21, days_diff_j = 61
#     weight = 0.1 / (|21 - 61| + 0.1) = 0.002494
#     term = 0.002494 * 4.3764901 = 0.010914
#
#   For i=10:
#     Sum of weights = 0.316045
#     Final result = 1.388126 / 0.316045 = 4.392173
#
#   For i=11, j=0:
#     days_diff_i = 24, days_diff_j = 1
#     weight = 0.1 / (|24 - 1| + 0.1) = 0.004329
# ...
#     days_diff_i = 63, days_diff_j = 63
#     weight = 0.1 / (|63 - 63| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=25, j=27:
#     days_diff_i = 63, days_diff_j = 59
#     weight = 0.1 / (|63 - 59| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=25, j=28:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#
#   For i=25:
#     Sum of weights = 2.419425
#     Final result = 10.589321 / 2.419425 = 4.376792
#
#   For i=26, j=0:
#     days_diff_i = 63, days_diff_j = 1
#     weight = 0.1 / (|63 - 1| + 0.1) = 0.001610
#     term = 0.001610 * 4.3473617 = 0.007001
#   For i=26, j=1:
#     days_diff_i = 63, days_diff_j = 1
#     weight = 0.1 / (|63 - 1| + 0.1) = 0.001610
#     term = 0.001610 * 4.3583495 = 0.007018
#   For i=26, j=2:
#     days_diff_i = 63, days_diff_j = 2
#     weight = 0.1 / (|63 - 2| + 0.1) = 0.001637
#     term = 0.001637 * 4.4000002 = 0.007201
#   For i=26, j=3:
#     days_diff_i = 63, days_diff_j = 1
#     weight = 0.1 / (|63 - 1| + 0.1) = 0.001610
#     term = 0.001610 * 4.4000009 = 0.007085
#   For i=26, j=4:
#     days_diff_i = 63, days_diff_j = 6
#     weight = 0.1 / (|63 - 6| + 0.1) = 0.001751
#     term = 0.001751 * 4.3967164 = 0.007700
#   For i=26, j=5:
#     days_diff_i = 63, days_diff_j = 10
#     weight = 0.1 / (|63 - 10| + 0.1) = 0.001883
#     term = 0.001883 * 4.3799998 = 0.008249
#   For i=26, j=6:
#     days_diff_i = 63, days_diff_j = 13
#     weight = 0.1 / (|63 - 13| + 0.1) = 0.001996
#     term = 0.001996 * 4.4000002 = 0.008782
#   For i=26, j=7:
#     days_diff_i = 63, days_diff_j = 15
#     weight = 0.1 / (|63 - 15| + 0.1) = 0.002079
#     term = 0.002079 * 4.4100002 = 0.009168
#   For i=26, j=8:
#     days_diff_i = 63, days_diff_j = 14
#     weight = 0.1 / (|63 - 14| + 0.1) = 0.002037
#     term = 0.002037 * 4.4 = 0.008961
#   For i=26, j=9:
#     days_diff_i = 63, days_diff_j = 20
#     weight = 0.1 / (|63 - 20| + 0.1) = 0.002320
#     term = 0.002320 * 4.3912443 = 0.010189
#   For i=26, j=10:
#     days_diff_i = 63, days_diff_j = 21
#     weight = 0.1 / (|63 - 21| + 0.1) = 0.002375
#     term = 0.002375 * 4.3579999 = 0.010352
#   For i=26, j=11:
#     days_diff_i = 63, days_diff_j = 24
#     weight = 0.1 / (|63 - 24| + 0.1) = 0.002558
#     term = 0.002558 * 4.4 = 0.011253
#   For i=26, j=12:
#     days_diff_i = 63, days_diff_j = 23
#     weight = 0.1 / (|63 - 23| + 0.1) = 0.002494
#     term = 0.002494 * 4.3725001 = 0.010904
#   For i=26, j=13:
#     days_diff_i = 63, days_diff_j = 26
#     weight = 0.1 / (|63 - 26| + 0.1) = 0.002695
#     term = 0.002695 * 4.4187439 = 0.011910
#   For i=26, j=14:
#     days_diff_i = 63, days_diff_j = 30
#     weight = 0.1 / (|63 - 30| + 0.1) = 0.003021
#     term = 0.003021 * 4.4300001 = 0.013384
#   For i=26, j=15:
#     days_diff_i = 63, days_diff_j = 37
#     weight = 0.1 / (|63 - 37| + 0.1) = 0.003831
#     term = 0.003831 * 4.42 = 0.016935
#   For i=26, j=16:
#     days_diff_i = 63, days_diff_j = 100
#     weight = 0.1 / (|63 - 100| + 0.1) = 0.002695
#     term = 0.002695 * 4.3915022 = 0.011837
#   For i=26, j=17:
#     days_diff_i = 63, days_diff_j = 92
#     weight = 0.1 / (|63 - 92| + 0.1) = 0.003436
#     term = 0.003436 * 4.3764901 = 0.015039
#   For i=26, j=18:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=26, j=19:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=26, j=20:
#     days_diff_i = 63, days_diff_j = 64
#     weight = 0.1 / (|63 - 64| + 0.1) = 0.090909
#     term = 0.090909 * 4.3764901 = 0.397863
#   For i=26, j=21:
#     days_diff_i = 63, days_diff_j = 59
#     weight = 0.1 / (|63 - 59| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=26, j=22:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=26, j=23:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=26, j=24:
#     days_diff_i = 63, days_diff_j = 63
#     weight = 0.1 / (|63 - 63| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=26, j=25:
#     days_diff_i = 63, days_diff_j = 63
#     weight = 0.1 / (|63 - 63| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=26, j=27:
#     days_diff_i = 63, days_diff_j = 59
#     weight = 0.1 / (|63 - 59| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=26, j=28:
#     days_diff_i = 63, days_diff_j = 61
#     weight = 0.1 / (|63 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#
#   For i=26:
#     Sum of weights = 2.419425
#     Final result = 10.589321 / 2.419425 = 4.376792
#
#   For i=27, j=0:
#     days_diff_i = 59, days_diff_j = 1
#     weight = 0.1 / (|59 - 1| + 0.1) = 0.001721
#     term = 0.001721 * 4.3473617 = 0.007483
#   For i=27, j=1:
#     days_diff_i = 59, days_diff_j = 1
#     weight = 0.1 / (|59 - 1| + 0.1) = 0.001721
#     term = 0.001721 * 4.3583495 = 0.007501
#   For i=27, j=2:
#     days_diff_i = 59, days_diff_j = 2
#     weight = 0.1 / (|59 - 2| + 0.1) = 0.001751
#     term = 0.001751 * 4.4000002 = 0.007706
#   For i=27, j=3:
#     days_diff_i = 59, days_diff_j = 1
#     weight = 0.1 / (|59 - 1| + 0.1) = 0.001721
#     term = 0.001721 * 4.4000009 = 0.007573
#   For i=27, j=4:
#     days_diff_i = 59, days_diff_j = 6
#     weight = 0.1 / (|59 - 6| + 0.1) = 0.001883
#     term = 0.001883 * 4.3967164 = 0.008280
#   For i=27, j=5:
#     days_diff_i = 59, days_diff_j = 10
#     weight = 0.1 / (|59 - 10| + 0.1) = 0.002037
#     term = 0.002037 * 4.3799998 = 0.008921
#   For i=27, j=6:
#     days_diff_i = 59, days_diff_j = 13
#     weight = 0.1 / (|59 - 13| + 0.1) = 0.002169
#     term = 0.002169 * 4.4000002 = 0.009544
#   For i=27, j=7:
#     days_diff_i = 59, days_diff_j = 15
#     weight = 0.1 / (|59 - 15| + 0.1) = 0.002268
#     term = 0.002268 * 4.4100002 = 0.010000
#   For i=27, j=8:
#     days_diff_i = 59, days_diff_j = 14
#     weight = 0.1 / (|59 - 14| + 0.1) = 0.002217
#     term = 0.002217 * 4.4 = 0.009756
#   For i=27, j=9:
#     days_diff_i = 59, days_diff_j = 20
#     weight = 0.1 / (|59 - 20| + 0.1) = 0.002558
#     term = 0.002558 * 4.3912443 = 0.011231
#   For i=27, j=10:
#     days_diff_i = 59, days_diff_j = 21
#     weight = 0.1 / (|59 - 21| + 0.1) = 0.002625
#     term = 0.002625 * 4.3579999 = 0.011438
#   For i=27, j=11:
#     days_diff_i = 59, days_diff_j = 24
#     weight = 0.1 / (|59 - 24| + 0.1) = 0.002849
#     term = 0.002849 * 4.4 = 0.012536
#   For i=27, j=12:
#     days_diff_i = 59, days_diff_j = 23
#     weight = 0.1 / (|59 - 23| + 0.1) = 0.002770
#     term = 0.002770 * 4.3725001 = 0.012112
#   For i=27, j=13:
#     days_diff_i = 59, days_diff_j = 26
#     weight = 0.1 / (|59 - 26| + 0.1) = 0.003021
#     term = 0.003021 * 4.4187439 = 0.013350
#   For i=27, j=14:
#     days_diff_i = 59, days_diff_j = 30
#     weight = 0.1 / (|59 - 30| + 0.1) = 0.003436
#     term = 0.003436 * 4.4300001 = 0.015223
#   For i=27, j=15:
#     days_diff_i = 59, days_diff_j = 37
#     weight = 0.1 / (|59 - 37| + 0.1) = 0.004525
#     term = 0.004525 * 4.42 = 0.020000
#   For i=27, j=16:
#     days_diff_i = 59, days_diff_j = 100
#     weight = 0.1 / (|59 - 100| + 0.1) = 0.002433
#     term = 0.002433 * 4.3915022 = 0.010685
#   For i=27, j=17:
#     days_diff_i = 59, days_diff_j = 92
#     weight = 0.1 / (|59 - 92| + 0.1) = 0.003021
#     term = 0.003021 * 4.3764901 = 0.013222
#   For i=27, j=18:
#     days_diff_i = 59, days_diff_j = 61
#     weight = 0.1 / (|59 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=27, j=19:
#     days_diff_i = 59, days_diff_j = 61
#     weight = 0.1 / (|59 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=27, j=20:
#     days_diff_i = 59, days_diff_j = 64
#     weight = 0.1 / (|59 - 64| + 0.1) = 0.019608
#     term = 0.019608 * 4.3764901 = 0.085814
#   For i=27, j=21:
#     days_diff_i = 59, days_diff_j = 59
#     weight = 0.1 / (|59 - 59| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=27, j=22:
#     days_diff_i = 59, days_diff_j = 61
#     weight = 0.1 / (|59 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=27, j=23:
#     days_diff_i = 59, days_diff_j = 61
#     weight = 0.1 / (|59 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=27, j=24:
#     days_diff_i = 59, days_diff_j = 63
#     weight = 0.1 / (|59 - 63| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=27, j=25:
#     days_diff_i = 59, days_diff_j = 63
#     weight = 0.1 / (|59 - 63| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=27, j=26:
#     days_diff_i = 59, days_diff_j = 63
#     weight = 0.1 / (|59 - 63| + 0.1) = 0.024390
#     term = 0.024390 * 4.3764901 = 0.106744
#   For i=27, j=28:
#     days_diff_i = 59, days_diff_j = 61
#     weight = 0.1 / (|59 - 61| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#
#   For i=27:
#     Sum of weights = 1.375601
#     Final result = 6.021117 / 1.375601 = 4.377082
#
#   For i=28, j=0:
#     days_diff_i = 61, days_diff_j = 1
#     weight = 0.1 / (|61 - 1| + 0.1) = 0.001664
#     term = 0.001664 * 4.3473617 = 0.007234
#   For i=28, j=1:
#     days_diff_i = 61, days_diff_j = 1
#     weight = 0.1 / (|61 - 1| + 0.1) = 0.001664
#     term = 0.001664 * 4.3583495 = 0.007252
#   For i=28, j=2:
#     days_diff_i = 61, days_diff_j = 2
#     weight = 0.1 / (|61 - 2| + 0.1) = 0.001692
#     term = 0.001692 * 4.4000002 = 0.007445
#   For i=28, j=3:
#     days_diff_i = 61, days_diff_j = 1
#     weight = 0.1 / (|61 - 1| + 0.1) = 0.001664
#     term = 0.001664 * 4.4000009 = 0.007321
#   For i=28, j=4:
#     days_diff_i = 61, days_diff_j = 6
#     weight = 0.1 / (|61 - 6| + 0.1) = 0.001815
#     term = 0.001815 * 4.3967164 = 0.007980
#   For i=28, j=5:
#     days_diff_i = 61, days_diff_j = 10
#     weight = 0.1 / (|61 - 10| + 0.1) = 0.001957
#     term = 0.001957 * 4.3799998 = 0.008571
#   For i=28, j=6:
#     days_diff_i = 61, days_diff_j = 13
#     weight = 0.1 / (|61 - 13| + 0.1) = 0.002079
#     term = 0.002079 * 4.4000002 = 0.009148
#   For i=28, j=7:
#     days_diff_i = 61, days_diff_j = 15
#     weight = 0.1 / (|61 - 15| + 0.1) = 0.002169
#     term = 0.002169 * 4.4100002 = 0.009566
#   For i=28, j=8:
#     days_diff_i = 61, days_diff_j = 14
#     weight = 0.1 / (|61 - 14| + 0.1) = 0.002123
#     term = 0.002123 * 4.4 = 0.009342
#   For i=28, j=9:
#     days_diff_i = 61, days_diff_j = 20
#     weight = 0.1 / (|61 - 20| + 0.1) = 0.002433
#     term = 0.002433 * 4.3912443 = 0.010684
#   For i=28, j=10:
#     days_diff_i = 61, days_diff_j = 21
#     weight = 0.1 / (|61 - 21| + 0.1) = 0.002494
#     term = 0.002494 * 4.3579999 = 0.010868
#   For i=28, j=11:
#     days_diff_i = 61, days_diff_j = 24
#     weight = 0.1 / (|61 - 24| + 0.1) = 0.002695
#     term = 0.002695 * 4.4 = 0.011860
#   For i=28, j=12:
#     days_diff_i = 61, days_diff_j = 23
#     weight = 0.1 / (|61 - 23| + 0.1) = 0.002625
#     term = 0.002625 * 4.3725001 = 0.011476
#   For i=28, j=13:
#     days_diff_i = 61, days_diff_j = 26
#     weight = 0.1 / (|61 - 26| + 0.1) = 0.002849
#     term = 0.002849 * 4.4187439 = 0.012589
#   For i=28, j=14:
#     days_diff_i = 61, days_diff_j = 30
#     weight = 0.1 / (|61 - 30| + 0.1) = 0.003215
#     term = 0.003215 * 4.4300001 = 0.014244
#   For i=28, j=15:
#     days_diff_i = 61, days_diff_j = 37
#     weight = 0.1 / (|61 - 37| + 0.1) = 0.004149
#     term = 0.004149 * 4.42 = 0.018340
#   For i=28, j=16:
#     days_diff_i = 61, days_diff_j = 100
#     weight = 0.1 / (|61 - 100| + 0.1) = 0.002558
#     term = 0.002558 * 4.3915022 = 0.011231
#   For i=28, j=17:
#     days_diff_i = 61, days_diff_j = 92
#     weight = 0.1 / (|61 - 92| + 0.1) = 0.003215
#     term = 0.003215 * 4.3764901 = 0.014072
#   For i=28, j=18:
#     days_diff_i = 61, days_diff_j = 61
#     weight = 0.1 / (|61 - 61| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=28, j=19:
#     days_diff_i = 61, days_diff_j = 61
#     weight = 0.1 / (|61 - 61| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=28, j=20:
#     days_diff_i = 61, days_diff_j = 64
#     weight = 0.1 / (|61 - 64| + 0.1) = 0.032258
#     term = 0.032258 * 4.3764901 = 0.141177
#   For i=28, j=21:
#     days_diff_i = 61, days_diff_j = 59
#     weight = 0.1 / (|61 - 59| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=28, j=22:
#     days_diff_i = 61, days_diff_j = 61
#     weight = 0.1 / (|61 - 61| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=28, j=23:
#     days_diff_i = 61, days_diff_j = 61
#     weight = 0.1 / (|61 - 61| + 0.1) = 1.000000
#     term = 1.000000 * 4.3764901 = 4.376490
#   For i=28, j=24:
#     days_diff_i = 61, days_diff_j = 63
#     weight = 0.1 / (|61 - 63| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=28, j=25:
#     days_diff_i = 61, days_diff_j = 63
#     weight = 0.1 / (|61 - 63| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=28, j=26:
#     days_diff_i = 61, days_diff_j = 63
#     weight = 0.1 / (|61 - 63| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#   For i=28, j=27:
#     days_diff_i = 61, days_diff_j = 59
#     weight = 0.1 / (|61 - 59| + 0.1) = 0.047619
#     term = 0.047619 * 4.3764901 = 0.208404
#
#   For i=28:
#     Sum of weights = 4.313414
#     Final result = 18.878383 / 4.313414 = 4.376668
#
#
# Final Result:
#    BUSINESS_DATE START_DATE   END_DATE  DAYS_DIFF  COMPOSITE_REPO_RATE  \
# 0     2025-05-06 2025-05-06 2025-05-07          1             4.347362
# 1     2025-05-06 2025-05-07 2025-05-08          1             4.358350
# 2     2025-05-06 2025-05-07 2025-05-09          2             4.400000
# 3     2025-05-06 2025-05-08 2025-05-09          1             4.400001
# 4     2025-05-06 2025-05-07 2025-05-13          6             4.396716
# 5     2025-05-06 2025-05-06 2025-05-16         10             4.380000
# 6     2025-05-06 2025-05-07 2025-05-20         13             4.400000
# 7     2025-05-06 2025-05-06 2025-05-21         15             4.410000
# 8     2025-05-06 2025-05-07 2025-05-21         14             4.400000
# 9     2025-05-06 2025-05-07 2025-05-27         20             4.391244
# 10    2025-05-06 2025-05-07 2025-05-28         21             4.358000
# 11    2025-05-06 2025-05-06 2025-05-30         24             4.400000
# 12    2025-05-06 2025-05-07 2025-05-30         23             4.372500
# 13    2025-05-06 2025-05-07 2025-06-02         26             4.418744
# 14    2025-05-06 2025-05-07 2025-06-06         30             4.430000
# 15    2025-05-06 2025-05-07 2025-06-13         37             4.420000
# 16    2025-05-06 2025-05-07 2025-08-15        100             4.391502
# 17    2025-05-06 2025-05-15 2025-08-15         92             4.376490
# 18    2025-05-06 2025-08-15 2025-10-15         61             4.376490
# 19    2025-05-06 2025-10-15 2025-12-15         61             4.376490
# 20    2025-05-06 2025-12-15 2026-02-17         64             4.376490
# 21    2025-05-06 2026-02-17 2026-04-17         59             4.376490
# 22    2025-05-06 2026-04-17 2026-06-17         61             4.376490
# 23    2025-05-06 2026-06-17 2026-08-17         61             4.376490
# 24    2025-05-06 2026-08-17 2026-10-19         63             4.376490
# 25    2025-05-06 2026-10-19 2026-12-21         63             4.376490
# 26    2025-05-06 2026-12-21 2027-02-22         63             4.376490
# 27    2025-05-06 2027-02-22 2027-04-22         59             4.376490
# 28    2025-05-06 2027-04-22 2027-06-22         61             4.376490
#
#     FINAL_OUTPUT
# 0       4.380643
# 1       4.375635
# 2       4.375494
# 3       4.356651
# 4       4.385584
# 5       4.391768
# 6       4.393220
# 7       4.391980
# 8       4.395563
# 9       4.382604
# 10      4.392173
# 11      4.388036
# 12      4.392809
# 13      4.390889
# 14      4.391509
# 15      4.389719
# 16      4.382188
# 17      4.384660
# 18      4.376668
# 19      4.376668
# 20      4.377875
# 21      4.377082
# 22      4.376668
# 23      4.376668
# 24      4.376792
# 25      4.376792
# 26      4.376792
# 27      4.377082
# 28      4.376668
#
# Results saved to repo_rate_calculation_results.csv

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Parse the input data
data = """BUSINESS DATE\tSTART DATE\tEND_DATE\tCOMPOSITE REPO_RATE  
5/6/2025\t5/6/2025\t5/7/2025\t4.3473617
5/6/2025\t5/7/2025\t5/8/2025\t4.3583495
5/6/2025\t5/7/2025\t5/9/2025\t4.4000002
5/6/2025\t5/8/2025\t5/9/2025\t4.4000009
5/6/2025\t5/7/2025\t5/13/2025\t4.3967164
5/6/2025\t5/6/2025\t5/16/2025\t4.3799998
5/6/2025\t5/7/2025\t5/20/2025\t4.4000002
5/6/2025\t5/6/2025\t5/21/2025\t4.4100002
5/6/2025\t5/7/2025\t5/21/2025\t4.4
5/6/2025\t5/7/2025\t5/27/2025\t4.3912443
5/6/2025\t5/7/2025\t5/28/2025\t4.3579999
5/6/2025\t5/6/2025\t5/30/2025\t4.4
5/6/2025\t5/7/2025\t5/30/2025\t4.3725001
5/6/2025\t5/7/2025\t6/2/2025\t4.4187439
5/6/2025\t5/7/2025\t6/6/2025\t4.4300001
5/6/2025\t5/7/2025\t6/13/2025\t4.42
5/6/2025\t5/7/2025\t8/15/2025\t4.3915022
5/6/2025\t5/15/2025\t8/15/2025\t4.3764901"""

# Convert to DataFrame
lines = data.strip().split('\n')
headers = [h.strip() for h in lines[0].split('\t')]
rows = []
for line in lines[1:]:
    row_data = line.split('\t')
    rows.append(row_data)

df = pd.DataFrame(rows, columns=headers)

# Convert dates to datetime objects
df['BUSINESS DATE'] = pd.to_datetime(df['BUSINESS DATE'], format='%m/%d/%Y')
df['START DATE'] = pd.to_datetime(df['START DATE'], format='%m/%d/%Y')
df['END_DATE'] = pd.to_datetime(df['END_DATE'], format='%m/%d/%Y')
df['COMPOSITE REPO_RATE'] = df['COMPOSITE REPO_RATE'].astype(float)

# Constant B_VALUE as given
B_VALUE = 0.1

# Function to calculate model rate
def calculate_model_rate(start_date, end_date, b_value):
    # Calculate repo length in years (using 360-day convention)
    repo_len = (end_date - start_date).days / 360
    
    # For this simple case, we have one interval, so exposure is equal to repo_len
    # In a more complex case, we would need to calculate exposures to multiple intervals
    expo = repo_len
    
    # Calculate tm_b_prod (dot product of exposure and b_value)
    tm_b_prod = expo * b_value
    
    # Calculate model rate
    model_rt = (np.exp(tm_b_prod) - 1) / repo_len
    
    return model_rt * 100  # Convert to percentage

# Calculate model rates for each row
calculated_rates = []
for index, row in df.iterrows():
    rate = calculate_model_rate(row['START DATE'], row['END_DATE'], B_VALUE)
    calculated_rates.append(rate)
    
    # Print step-by-step calculation for the first few rows
    if index < 3:
        i = index + 1
        repo_len = (row['END_DATE'] - row['START DATE']).days / 360
        expo = repo_len
        tm_b_prod = expo * B_VALUE
        model_rt = (np.exp(tm_b_prod) - 1) / repo_len
        
        print(f"Row {i}:")
        print(f"  Start Date: {row['START DATE'].strftime('%m/%d/%Y')}")
        print(f"  End Date: {row['END_DATE'].strftime('%m/%d/%Y')}")
        print(f"  repo_len = ({row['END_DATE'].strftime('%m/%d/%Y')} - {row['START DATE'].strftime('%m/%d/%Y')}) / 360 = {repo_len:.6f}")
        print(f"  expo = {expo:.6f}")
        print(f"  tm_b_prod = {expo:.6f} * {B_VALUE} = {tm_b_prod:.6f}")
        print(f"  model_rt = (e^{tm_b_prod:.6f} - 1) / {repo_len:.6f} = {model_rt * 100:.6f}%")
        print(f"  Expected rate: {row['COMPOSITE REPO_RATE']}%")
        print()

# Add calculated rates to DataFrame
df['CALCULATED RATE'] = calculated_rates

# Compare calculated rates with expected rates
df['DIFFERENCE'] = df['CALCULATED RATE'] - df['COMPOSITE REPO_RATE']

# Display results
print("Comparison of calculated vs expected rates:")
comparison_df = df[['START DATE', 'END_DATE', 'COMPOSITE REPO_RATE', 'CALCULATED RATE', 'DIFFERENCE']]
print(comparison_df.to_string(float_format=lambda x: f"{x:.6f}"))
# Out:
# Row 1:
#   Start Date: 05/06/2025
#   End Date: 05/07/2025
#   repo_len = (05/07/2025 - 05/06/2025) / 360 = 0.002778
#   expo = 0.002778
#   tm_b_prod = 0.002778 * 0.1 = 0.000278
#   model_rt = (e^0.000278 - 1) / 0.002778 = 10.001389%
#   Expected rate: 4.3473617%
#
# Row 2:
#   Start Date: 05/07/2025
#   End Date: 05/08/2025
#   repo_len = (05/08/2025 - 05/07/2025) / 360 = 0.002778
#   expo = 0.002778
#   tm_b_prod = 0.002778 * 0.1 = 0.000278
#   model_rt = (e^0.000278 - 1) / 0.002778 = 10.001389%
#   Expected rate: 4.3583495%
#
# Row 3:
#   Start Date: 05/07/2025
#   End Date: 05/09/2025
#   repo_len = (05/09/2025 - 05/07/2025) / 360 = 0.005556
#   expo = 0.005556
#   tm_b_prod = 0.005556 * 0.1 = 0.000556
#   model_rt = (e^0.000556 - 1) / 0.005556 = 10.002778%
#   Expected rate: 4.4000002%
#
# Comparison of calculated vs expected rates:
#    START DATE   END_DATE  COMPOSITE REPO_RATE  CALCULATED RATE  DIFFERENCE
# 0  2025-05-06 2025-05-07             4.347362        10.001389    5.654027
# 1  2025-05-07 2025-05-08             4.358350        10.001389    5.643040
# 2  2025-05-07 2025-05-09             4.400000        10.002778    5.602778
# 3  2025-05-08 2025-05-09             4.400001        10.001389    5.601388
# 4  2025-05-07 2025-05-13             4.396716        10.008338    5.611622
# 5  2025-05-06 2025-05-16             4.380000        10.013902    5.633902
# 6  2025-05-07 2025-05-20             4.400000        10.018077    5.618077
# 7  2025-05-06 2025-05-21             4.410000        10.020862    5.610862
# 8  2025-05-07 2025-05-21             4.400000        10.019470    5.619470
# 9  2025-05-07 2025-05-27             4.391244        10.027829    5.636585
# 10 2025-05-07 2025-05-28             4.358000        10.029223    5.671224
# 11 2025-05-06 2025-05-30             4.400000        10.033408    5.633408
# 12 2025-05-07 2025-05-30             4.372500        10.032013    5.659512
# 13 2025-05-07 2025-06-02             4.418744        10.036198    5.617454
# 14 2025-05-07 2025-06-06             4.430000        10.041783    5.611783
# 15 2025-05-07 2025-06-13             4.420000        10.051565    5.631565
# 16 2025-05-07 2025-08-15             4.391502        10.140184    5.748682
# 17 2025-05-15 2025-08-15             4.376490        10.128873    5.752383
